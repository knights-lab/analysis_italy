# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# numpy   1.18.4
# seaborn 0.10.1
# pandas  1.0.4

# %%
data_folder = "/mnt/btrfs/data/italy"

# %%
metadata_file = "data/metadata.csv"

# %%
df_metadata_file = pd.read_csv(metadata_file, sep=",")

# %%
df_metadata_file.columns
# Out:
# Index(['sample_id', 'Sample_Number', 'Sample_Code', 'Shotgun', '16s',
#        'viral_load', 'nCoVN1', 'nCoVN2', 'RNase P', 'ConcN1', 'ConcN2', 'N1',
#        'Sex', 'Age', 'Age_range', 'Age_average', 'Blood_sampling_date',
#        'Swab date', 'Severe_Case', 'REUMA', 'PNEUMO', 'ONCO', 'HEMATO',
#        'DIABETES', 'METABOLIC', 'CARDIO', 'HYPERTENSION', 'NEPHRO', 'TB',
#        'HIV', 'IMMUNOSUPPRESSION', 'HEPATOPATHY', 'HCQ', 'LPV', 'HCQ_LPV',
#        'HCQ_LPV_01', 'HCQ_LPV_02', 'RDV', 'TCZ', 'BCT', 'Steroide',
#        'SYMPTOMS_ONSET', 'SYMPTOMS_TO_SWAB_DAYS', 'Swab_day_quartile',
#        'Set_severe', 'swab_days_avg', 'SD_q1_severe', 'SD_q1_HB02', 'swab_out',
#        'OUTCOME', 'Hospitalization_Days', 'CRP', 'CRP_range', 'LDH',
#        'LDH_range', 'Ferritin', 'CPK', 'CPK_range', 'WBC', 'WBC_range',
#        'Neutrophil_Count', 'AST', 'ALT', 'Albumin', 'D.Dimer', 'Lowest_SpO2',
#        'Hospital_bin', 'Hospital_bin_01', 'Hospital_bin_02', 'q1', 'bin_02',
#        'HCQ.1', 'LPV.1', 'HB_02_HCQ', 'HB_02_LVD', 'Out_age_range'],
#       dtype='object')

# %%
df_metadata_file["RDV"].value_counts()
# Out:
# No     68
# Yes    32
# Name: RDV, dtype: int64

# %%
taxatable = "/mnt/btrfs/data/italy/taxatable/filter_qc_taxatable.txt"

# %%
df_taxa_raw = pd.read_csv(taxatable, sep="\t", index_col=0)

# %%
columns = df_taxa_raw.columns

# %%
sample_ids = ["_".join(_.split(".")[:2]) if not _.startswith("pos") else "_".join(_.split(".")[:3]) for _ in columns]

# %%
df_taxa = df_taxa_raw.copy().T

# %%
df_taxa_ra = df_taxa.apply(lambda x: x / x.sum(), axis=1)

print(df_taxa_ra.sum(axis=1))
# Out:
# pos.dna.02.S35.001.fa    1.0
# CAPMA.83.S12.001.fa      1.0
# FOGI.63.S13.001.fa       1.0
# COCL.11.S7.001.fa        1.0
# WACH.38.S1.001.fa        1.0
# PRPI.42.S31.001.fa       1.0
# RODE.80.S8.001.fa        1.0
# pos.dna.01.S17.001.fa    1.0
# MEEN.93.S11.001.fa       1.0
# DETH.41.S27.001.fa       1.0
# TECA.45.S15.001.fa       1.0
# BODA.52.S9.001.fa        1.0
# CHMA.61.S3.001.fa        1.0
# ASTER.02.S34.001.fa      1.0
# BIRO.74.S19.001.fa       1.0
# CAAU.07.S2.001.fa        1.0
# DIGMA.71.S21.001.fa      1.0
# FAFE.16.S10.001.fa       1.0
# OPSE.53.S5.001.fa        1.0
# LAES.91.S29.001.fa       1.0
# DOEC.81.S30.001.fa       1.0
# EKJO.64.S32.001.fa       1.0
# DIAL.15.S23.001.fa       1.0
# GIFI.21.S22.001.fa       1.0
# TAOT.65.S24.001.fa       1.0
# DEFI.14.S6.001.fa        1.0
# MUNA.98.S28.001.fa       1.0
# ROAL.75.S33.001.fa       1.0
# MERI.28.S20.001.fa       1.0
# BUMA.05.S4.001.fa        1.0
# MOEM.48.S16.001.fa       1.0
# PAMA.46.S18.001.fa       1.0
# VUGE.37.S14.001.fa       1.0
# TOSA.76.S25.001.fa       1.0
# DEIS.70.S26.001.fa       1.0
# dtype: float64

# %%
(df_taxa.mean(axis=0) / df_taxa.mean().sum())[genera]
# Out:
# #OTU ID
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_atypica             2.851332e-03
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_rogosae             3.755483e-03
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_parvula             1.260326e-03
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_dispar              2.185924e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_tobetsuensis        2.696719e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_parvula_A           2.443783e-03
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900552445         3.482613e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900549845         3.694330e-05
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_dispar_A            6.185859e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp003463825         1.172892e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_montpellierensis    4.341006e-06
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_seminalis       2.523844e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900550175         8.987449e-05
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp002959755         2.335864e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900556785         4.074784e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900552715         1.032947e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_sp000431435     3.440359e-05
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_rodentium           1.286452e-05
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_infantium           1.252720e-04
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_criceti         3.058097e-07
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_ratti           4.754968e-07
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900538355         6.638122e-05
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_caviae              3.746169e-06
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_magna           8.018181e-08
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_denticariosi        9.687082e-06
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900545205         3.817587e-05
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_sp900545795     1.864693e-09
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900549805         2.610571e-08
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900550455         1.139328e-06
# dtype: float64

# %%
(((df_taxa > 0).sum(axis=0)) / df_taxa.shape[0])[genera]
# Out:
# #OTU ID
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_atypica             0.971429
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_rogosae             0.971429
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_parvula             0.914286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_dispar              0.914286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_tobetsuensis        0.771429
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_parvula_A           0.942857
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900552445         0.857143
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900549845         0.828571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_dispar_A            0.914286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp003463825         0.828571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_montpellierensis    0.742857
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_seminalis       0.828571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900550175         0.771429
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp002959755         0.942857
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900556785         0.914286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900552715         0.742857
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_sp000431435     0.828571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_rodentium           0.628571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_infantium           0.857143
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_criceti         0.142857
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_ratti           0.171429
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900538355         0.742857
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_caviae              0.428571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_magna           0.314286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_denticariosi        0.514286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900545205         0.628571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella_A;s__Veillonella_A_sp900545795     0.028571
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900549805         0.114286
# k__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella;s__Veillonella_sp900550455         0.228571
# dtype: float64

# %%
genus = "g__Veillonella"

genera = [col for col in df_taxa.columns if genus in col]

for species in genera:
    print(df_taxa_ra.loc[:, species].mean())
# Out:
# 0.0036772251058606437
# 0.0056389236160887075
# 0.002186069515610472
# 0.00041927854251735307
# 0.0003574163793665351
# 0.0040247657932257945
# 0.0005146253983254719
# 6.105916470448266e-05
# 0.0011684249338513872
# 0.00020648962167528102
# 4.72115014996214e-06
# 0.00029510066075474765
# 0.00015088308544970556
# 0.0004143575493339903
# 0.0007157524851392719
# 0.00015809464732849724
# 3.595941007504857e-05
# 2.2662311391491095e-05
# 0.00021912281026804502
# 4.14592475827635e-07
# 7.859542155777695e-07
# 0.00011046211409347521
# 7.075057341688369e-06
# 9.283664667603348e-08
# 1.7363778223646576e-05
# 6.744169158907973e-05
# 1.5316721072936311e-09
# 3.123461795789539e-08
# 1.5660990319765224e-06

# %%
df_taxa.shape
# Out:
# (35, 7513)

# %%
# we only want species present in greater than 95% of the samples
mask_low_prevalence = ((df_taxa > 0).sum(axis=0)) / df_taxa.shape[0] >= .8

# %%
# mask low abundance
mask_low_abundance = (df_taxa.median(axis=0) / df_taxa.median().sum()) >= .0001

mask_low_abundance.sum()
# Out:
# 455

# %%
df_taxa = df_taxa.loc[:, mask_low_prevalence & mask_low_abundance]

# %%
df_taxa_export = df_taxa.reset_index().copy()

# %%
list(df_taxa_export.columns)[-1]
# Out:
# 'k__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Clostridium_Q;s__Clostridium_Q_saccharolyticum_A'

# %%
sample_ids = ["_".join(_.split(".")[:2]) if not _.startswith("pos") else "_".join(_.split(".")[:3]) for _ in df_taxa_export["index"]]

df_taxa_export["index"] = sample_ids
df_taxa_export.loc[df_taxa_export["index"] == "MERI_28", "index"] = "MEIR_28"

# %%
cols = list(df_taxa_export.columns)

cols[0] = "SampleID"

df_taxa_export.columns = cols

# %%
df_taxa_export.T.to_csv("./data/shogun.98.p8.la0001.csv", index=True, header=False)

# %%
from skbio.stats.composition import clr
# Out:
# /home/bhillmann/.conda/envs/type_1/lib/python3.8/site-packages/skbio/sequence/_sequence.py:28: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   collections.Sequence, SkbioObject):
# /home/bhillmann/.conda/envs/type_1/lib/python3.8/site-packages/skbio/io/format/gff3.py:217: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Iterable
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
df_taxa_clr = df_taxa.copy()

# %%
df_taxa_clr = pd.DataFrame(clr(df_taxa + 1))

# %%
df_taxa_clr.columns = df_taxa.columns
df_taxa_clr.index = df_taxa.index

# %%
df_taxa_clr
# Out:
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Phocaeicola;s__Phocaeicola_vulgatus  \
# pos.dna.02.S35.001.fa                                          12.564805
# CAPMA.83.S12.001.fa                                             1.502473
# FOGI.63.S13.001.fa                                              3.594296
# COCL.11.S7.001.fa                                               1.536088
# WACH.38.S1.001.fa                                               4.240597
# PRPI.42.S31.001.fa                                              3.169797
# RODE.80.S8.001.fa                                               5.918568
# pos.dna.01.S17.001.fa                                          10.758325
# MEEN.93.S11.001.fa                                              4.110142
# DETH.41.S27.001.fa                                              3.183976
# TECA.45.S15.001.fa                                              3.134289
# BODA.52.S9.001.fa                                               4.091882
# CHMA.61.S3.001.fa                                               6.751274
# ASTER.02.S34.001.fa                                             7.511852
# BIRO.74.S19.001.fa                                              6.603156
# CAAU.07.S2.001.fa                                               5.567414
# DIGMA.71.S21.001.fa                                             5.374936
# FAFE.16.S10.001.fa                                              5.584302
# OPSE.53.S5.001.fa                                               7.120223
# LAES.91.S29.001.fa                                              3.183280
# DOEC.81.S30.001.fa                                              4.092462
# EKJO.64.S32.001.fa                                              2.758383
# DIAL.15.S23.001.fa                                              4.740969
# GIFI.21.S22.001.fa                                              3.184368
# TAOT.65.S24.001.fa                                              2.689188
# DEFI.14.S6.001.fa                                               3.475730
# MUNA.98.S28.001.fa                                              2.218994
# ROAL.75.S33.001.fa                                              2.617716
# MERI.28.S20.001.fa                                              1.645391
# BUMA.05.S4.001.fa                                               5.184688
# MOEM.48.S16.001.fa                                              5.631256
# PAMA.46.S18.001.fa                                              2.826640
# VUGE.37.S14.001.fa                                              4.700142
# TOSA.76.S25.001.fa                                              2.213781
# DEIS.70.S26.001.fa                                              2.781823
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_fragilis  \
# pos.dna.02.S35.001.fa                                          12.596202
# CAPMA.83.S12.001.fa                                             0.108900
# FOGI.63.S13.001.fa                                             -0.611240
# COCL.11.S7.001.fa                                               1.074962
# WACH.38.S1.001.fa                                              -0.421227
# PRPI.42.S31.001.fa                                             -1.438640
# RODE.80.S8.001.fa                                              -1.343871
# pos.dna.01.S17.001.fa                                          10.466699
# MEEN.93.S11.001.fa                                              6.091029
# DETH.41.S27.001.fa                                             -3.761992
# TECA.45.S15.001.fa                                              4.631672
# BODA.52.S9.001.fa                                               1.095134
# CHMA.61.S3.001.fa                                               1.924646
# ASTER.02.S34.001.fa                                            -0.131282
# BIRO.74.S19.001.fa                                              4.111350
# CAAU.07.S2.001.fa                                              -1.544217
# DIGMA.71.S21.001.fa                                             0.454759
# FAFE.16.S10.001.fa                                             -0.067135
# OPSE.53.S5.001.fa                                               1.635535
# LAES.91.S29.001.fa                                             -0.423308
# DOEC.81.S30.001.fa                                             -0.679445
# EKJO.64.S32.001.fa                                              1.899094
# DIAL.15.S23.001.fa                                              4.392127
# GIFI.21.S22.001.fa                                              2.202335
# TAOT.65.S24.001.fa                                              1.152850
# DEFI.14.S6.001.fa                                               5.737301
# MUNA.98.S28.001.fa                                             -1.491165
# ROAL.75.S33.001.fa                                              0.620977
# MERI.28.S20.001.fa                                             -2.516686
# BUMA.05.S4.001.fa                                               0.726147
# MOEM.48.S16.001.fa                                              1.947917
# PAMA.46.S18.001.fa                                              1.425925
# VUGE.37.S14.001.fa                                             -1.786927
# TOSA.76.S25.001.fa                                              6.897451
# DEIS.70.S26.001.fa                                              1.181892
#
# #OTU ID                k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia_coli  \
# pos.dna.02.S35.001.fa                                          10.432703
# CAPMA.83.S12.001.fa                                             8.026002
# FOGI.63.S13.001.fa                                              0.322862
# COCL.11.S7.001.fa                                               4.663100
# WACH.38.S1.001.fa                                               2.999156
# PRPI.42.S31.001.fa                                              7.172793
# RODE.80.S8.001.fa                                               4.211689
# pos.dna.01.S17.001.fa                                           8.427199
# MEEN.93.S11.001.fa                                              4.004449
# DETH.41.S27.001.fa                                             -0.928224
# TECA.45.S15.001.fa                                              2.388486
# BODA.52.S9.001.fa                                               0.574600
# CHMA.61.S3.001.fa                                               3.074376
# ASTER.02.S34.001.fa                                            -3.570534
# BIRO.74.S19.001.fa                                             -1.495615
# CAAU.07.S2.001.fa                                              -4.652267
# DIGMA.71.S21.001.fa                                            -1.006752
# FAFE.16.S10.001.fa                                             -1.416951
# OPSE.53.S5.001.fa                                               1.917310
# LAES.91.S29.001.fa                                              5.162297
# DOEC.81.S30.001.fa                                              3.202142
# EKJO.64.S32.001.fa                                              3.268204
# DIAL.15.S23.001.fa                                              1.668718
# GIFI.21.S22.001.fa                                             -0.188357
# TAOT.65.S24.001.fa                                              0.797345
# DEFI.14.S6.001.fa                                               3.139103
# MUNA.98.S28.001.fa                                             -1.683421
# ROAL.75.S33.001.fa                                              1.251969
# MERI.28.S20.001.fa                                              6.880540
# BUMA.05.S4.001.fa                                              -1.573127
# MOEM.48.S16.001.fa                                             -1.263681
# PAMA.46.S18.001.fa                                              0.920859
# VUGE.37.S14.001.fa                                              4.158713
# TOSA.76.S25.001.fa                                             -1.166429
# DEIS.70.S26.001.fa                                              1.358823
#
# #OTU ID                k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia_coli_D  \
# pos.dna.02.S35.001.fa                                          10.382420
# CAPMA.83.S12.001.fa                                             6.006419
# FOGI.63.S13.001.fa                                             -0.505445
# COCL.11.S7.001.fa                                               3.188711
# WACH.38.S1.001.fa                                               1.341303
# PRPI.42.S31.001.fa                                              4.708191
# RODE.80.S8.001.fa                                               4.242758
# pos.dna.01.S17.001.fa                                           8.411471
# MEEN.93.S11.001.fa                                              3.807656
# DETH.41.S27.001.fa                                             -2.920100
# TECA.45.S15.001.fa                                              3.961840
# BODA.52.S9.001.fa                                              -0.936630
# CHMA.61.S3.001.fa                                               2.536282
# ASTER.02.S34.001.fa                                            -3.458830
# BIRO.74.S19.001.fa                                             -1.615759
# CAAU.07.S2.001.fa                                              -5.025247
# DIGMA.71.S21.001.fa                                             0.006649
# FAFE.16.S10.001.fa                                             -2.181225
# OPSE.53.S5.001.fa                                              -0.146372
# LAES.91.S29.001.fa                                              3.618158
# DOEC.81.S30.001.fa                                              3.084641
# EKJO.64.S32.001.fa                                              1.459727
# DIAL.15.S23.001.fa                                              0.472244
# GIFI.21.S22.001.fa                                             -0.344703
# TAOT.65.S24.001.fa                                             -1.012114
# DEFI.14.S6.001.fa                                               5.188512
# MUNA.98.S28.001.fa                                             -2.960675
# ROAL.75.S33.001.fa                                              0.998512
# MERI.28.S20.001.fa                                              5.298956
# BUMA.05.S4.001.fa                                              -1.091536
# MOEM.48.S16.001.fa                                             -1.753768
# PAMA.46.S18.001.fa                                             -0.381243
# VUGE.37.S14.001.fa                                              1.681301
# TOSA.76.S25.001.fa                                             -0.946432
# DEIS.70.S26.001.fa                                              0.169754
#
# #OTU ID                k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia_flexneri  \
# pos.dna.02.S35.001.fa                                          10.717464
# CAPMA.83.S12.001.fa                                             4.688253
# FOGI.63.S13.001.fa                                             -2.583584
# COCL.11.S7.001.fa                                               1.774582
# WACH.38.S1.001.fa                                               0.023436
# PRPI.42.S31.001.fa                                              3.824696
# RODE.80.S8.001.fa                                               4.215763
# pos.dna.01.S17.001.fa                                           8.758813
# MEEN.93.S11.001.fa                                              2.422215
# DETH.41.S27.001.fa                                             -3.462587
# TECA.45.S15.001.fa                                             -0.605582
# BODA.52.S9.001.fa                                              -1.537898
# CHMA.61.S3.001.fa                                               1.136575
# ASTER.02.S34.001.fa                                            -3.434732
# BIRO.74.S19.001.fa                                             -2.541918
# CAAU.07.S2.001.fa                                              -6.750757
# DIGMA.71.S21.001.fa                                            -1.588852
# FAFE.16.S10.001.fa                                             -2.503694
# OPSE.53.S5.001.fa                                              -1.667841
# LAES.91.S29.001.fa                                              2.340659
# DOEC.81.S30.001.fa                                              3.229331
# EKJO.64.S32.001.fa                                              1.149572
# DIAL.15.S23.001.fa                                             -1.063350
# GIFI.21.S22.001.fa                                             -0.019281
# TAOT.65.S24.001.fa                                             -2.398408
# DEFI.14.S6.001.fa                                               0.212743
# MUNA.98.S28.001.fa                                             -3.069716
# ROAL.75.S33.001.fa                                              1.236305
# MERI.28.S20.001.fa                                              5.544301
# BUMA.05.S4.001.fa                                              -2.000538
# MOEM.48.S16.001.fa                                             -2.266186
# PAMA.46.S18.001.fa                                             -0.867528
# VUGE.37.S14.001.fa                                              0.816839
# TOSA.76.S25.001.fa                                             -1.813533
# DEIS.70.S26.001.fa                                             -0.047490
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_bouchesdurhonensis  \
# pos.dna.02.S35.001.fa                                          -0.529343
# CAPMA.83.S12.001.fa                                            -3.136293
# FOGI.63.S13.001.fa                                             -0.913521
# COCL.11.S7.001.fa                                              -2.081677
# WACH.38.S1.001.fa                                              -1.574201
# PRPI.42.S31.001.fa                                             -0.532085
# RODE.80.S8.001.fa                                              -0.235021
# pos.dna.01.S17.001.fa                                          -1.616304
# MEEN.93.S11.001.fa                                             -0.461099
# DETH.41.S27.001.fa                                              0.307518
# TECA.45.S15.001.fa                                             -0.851349
# BODA.52.S9.001.fa                                               0.710902
# CHMA.61.S3.001.fa                                               1.722341
# ASTER.02.S34.001.fa                                             0.951255
# BIRO.74.S19.001.fa                                             -0.057356
# CAAU.07.S2.001.fa                                              -0.619196
# DIGMA.71.S21.001.fa                                            -0.308543
# FAFE.16.S10.001.fa                                              1.577985
# OPSE.53.S5.001.fa                                               1.399707
# LAES.91.S29.001.fa                                             -0.533104
# DOEC.81.S30.001.fa                                             -0.325333
# EKJO.64.S32.001.fa                                              2.914325
# DIAL.15.S23.001.fa                                             -0.037714
# GIFI.21.S22.001.fa                                              2.197504
# TAOT.65.S24.001.fa                                             -0.606649
# DEFI.14.S6.001.fa                                              -1.604646
# MUNA.98.S28.001.fa                                             -2.292634
# ROAL.75.S33.001.fa                                             -0.857894
# MERI.28.S20.001.fa                                             -2.042753
# BUMA.05.S4.001.fa                                              -1.530629
# MOEM.48.S16.001.fa                                              0.196565
# PAMA.46.S18.001.fa                                             -1.068199
# VUGE.37.S14.001.fa                                             -1.146786
# TOSA.76.S25.001.fa                                             -1.793730
# DEIS.70.S26.001.fa                                              4.855276
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Tannerellaceae;g__Parabacteroides;s__Parabacteroides_distasonis_A  \
# pos.dna.02.S35.001.fa                                          -0.683494
# CAPMA.83.S12.001.fa                                             0.814951
# FOGI.63.S13.001.fa                                             -0.274768
# COCL.11.S7.001.fa                                              -2.133863
# WACH.38.S1.001.fa                                              -1.208627
# PRPI.42.S31.001.fa                                              0.522833
# RODE.80.S8.001.fa                                               1.030012
# pos.dna.01.S17.001.fa                                          -0.923157
# MEEN.93.S11.001.fa                                              0.197382
# DETH.41.S27.001.fa                                             -3.401551
# TECA.45.S15.001.fa                                              0.515884
# BODA.52.S9.001.fa                                              -0.204385
# CHMA.61.S3.001.fa                                               1.558442
# ASTER.02.S34.001.fa                                             1.994439
# BIRO.74.S19.001.fa                                             -0.108232
# CAAU.07.S2.001.fa                                               1.828631
# DIGMA.71.S21.001.fa                                            -0.375151
# FAFE.16.S10.001.fa                                              0.749284
# OPSE.53.S5.001.fa                                               3.893911
# LAES.91.S29.001.fa                                             -2.047337
# DOEC.81.S30.001.fa                                              1.312362
# EKJO.64.S32.001.fa                                             -1.524576
# DIAL.15.S23.001.fa                                              1.751842
# GIFI.21.S22.001.fa                                             -1.151795
# TAOT.65.S24.001.fa                                             -1.571730
# DEFI.14.S6.001.fa                                               0.610018
# MUNA.98.S28.001.fa                                             -0.164856
# ROAL.75.S33.001.fa                                             -0.566466
# MERI.28.S20.001.fa                                              0.192413
# BUMA.05.S4.001.fa                                               0.112467
# MOEM.48.S16.001.fa                                              2.102101
# PAMA.46.S18.001.fa                                             -2.690059
# VUGE.37.S14.001.fa                                              0.389677
# TOSA.76.S25.001.fa                                              1.110166
# DEIS.70.S26.001.fa                                             -1.869103
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_uniformis  \
# pos.dna.02.S35.001.fa                                           5.178716
# CAPMA.83.S12.001.fa                                             1.198817
# FOGI.63.S13.001.fa                                              2.714890
# COCL.11.S7.001.fa                                               1.997295
# WACH.38.S1.001.fa                                               2.685130
# PRPI.42.S31.001.fa                                              2.376027
# RODE.80.S8.001.fa                                               2.403992
# pos.dna.01.S17.001.fa                                           3.486100
# MEEN.93.S11.001.fa                                              3.913378
# DETH.41.S27.001.fa                                              1.633435
# TECA.45.S15.001.fa                                              3.626052
# BODA.52.S9.001.fa                                               2.611502
# CHMA.61.S3.001.fa                                               6.117136
# ASTER.02.S34.001.fa                                             3.549830
# BIRO.74.S19.001.fa                                              4.973692
# CAAU.07.S2.001.fa                                               5.706051
# DIGMA.71.S21.001.fa                                             6.540831
# FAFE.16.S10.001.fa                                              5.106302
# OPSE.53.S5.001.fa                                               4.110070
# LAES.91.S29.001.fa                                              4.861458
# DOEC.81.S30.001.fa                                              3.325615
# EKJO.64.S32.001.fa                                              1.952459
# DIAL.15.S23.001.fa                                              3.866595
# GIFI.21.S22.001.fa                                              2.699819
# TAOT.65.S24.001.fa                                              3.131588
# DEFI.14.S6.001.fa                                               3.058043
# MUNA.98.S28.001.fa                                              4.237870
# ROAL.75.S33.001.fa                                              2.787953
# MERI.28.S20.001.fa                                              2.897733
# BUMA.05.S4.001.fa                                               4.452070
# MOEM.48.S16.001.fa                                              4.604422
# PAMA.46.S18.001.fa                                              2.445372
# VUGE.37.S14.001.fa                                              2.790468
# TOSA.76.S25.001.fa                                              2.397261
# DEIS.70.S26.001.fa                                              2.909639
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_faecis  \
# pos.dna.02.S35.001.fa                                           1.714401
# CAPMA.83.S12.001.fa                                             3.197282
# FOGI.63.S13.001.fa                                              0.887994
# COCL.11.S7.001.fa                                               2.537797
# WACH.38.S1.001.fa                                               0.050759
# PRPI.42.S31.001.fa                                              1.803052
# RODE.80.S8.001.fa                                               1.124451
# pos.dna.01.S17.001.fa                                           2.323658
# MEEN.93.S11.001.fa                                              1.410490
# DETH.41.S27.001.fa                                              0.197562
# TECA.45.S15.001.fa                                             -0.435956
# BODA.52.S9.001.fa                                               1.548782
# CHMA.61.S3.001.fa                                               3.203964
# ASTER.02.S34.001.fa                                             2.011697
# BIRO.74.S19.001.fa                                              1.036538
# CAAU.07.S2.001.fa                                               1.065846
# DIGMA.71.S21.001.fa                                             0.876363
# FAFE.16.S10.001.fa                                              6.007668
# OPSE.53.S5.001.fa                                               1.131665
# LAES.91.S29.001.fa                                             -0.527922
# DOEC.81.S30.001.fa                                              4.108773
# EKJO.64.S32.001.fa                                              1.117723
# DIAL.15.S23.001.fa                                             -0.562924
# GIFI.21.S22.001.fa                                              1.567684
# TAOT.65.S24.001.fa                                             -0.432295
# DEFI.14.S6.001.fa                                              -0.740189
# MUNA.98.S28.001.fa                                             -0.495943
# ROAL.75.S33.001.fa                                             -0.119041
# MERI.28.S20.001.fa                                              0.579711
# ...
# TOSA.76.S25.001.fa                                             -2.781117
# DEIS.70.S26.001.fa                                             -3.350707
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Paraprevotella;s__Paraprevotella_sp003477995  \
# pos.dna.02.S35.001.fa                                          -2.475253
# CAPMA.83.S12.001.fa                                            -2.443146
# FOGI.63.S13.001.fa                                             -2.626143
# COCL.11.S7.001.fa                                              -3.594266
# WACH.38.S1.001.fa                                              -1.953475
# PRPI.42.S31.001.fa                                             -1.227844
# RODE.80.S8.001.fa                                              -1.467165
# pos.dna.01.S17.001.fa                                          -2.714916
# MEEN.93.S11.001.fa                                             -3.596317
# DETH.41.S27.001.fa                                             -0.362683
# TECA.45.S15.001.fa                                             -2.342227
# BODA.52.S9.001.fa                                              -0.727855
# CHMA.61.S3.001.fa                                               0.590895
# ASTER.02.S34.001.fa                                             1.110924
# BIRO.74.S19.001.fa                                              1.265571
# CAAU.07.S2.001.fa                                               0.328233
# DIGMA.71.S21.001.fa                                             0.604328
# FAFE.16.S10.001.fa                                             -0.797606
# OPSE.53.S5.001.fa                                               0.762726
# LAES.91.S29.001.fa                                             -2.009986
# DOEC.81.S30.001.fa                                             -2.681997
# EKJO.64.S32.001.fa                                             -3.517006
# DIAL.15.S23.001.fa                                             -1.053558
# GIFI.21.S22.001.fa                                             -2.909653
# TAOT.65.S24.001.fa                                             -2.264877
# DEFI.14.S6.001.fa                                              -3.090619
# MUNA.98.S28.001.fa                                             -4.406562
# ROAL.75.S33.001.fa                                             -2.515834
# MERI.28.S20.001.fa                                             -3.217738
# BUMA.05.S4.001.fa                                              -2.212961
# MOEM.48.S16.001.fa                                             -0.922624
# PAMA.46.S18.001.fa                                             -1.335513
# VUGE.37.S14.001.fa                                             -2.197253
# TOSA.76.S25.001.fa                                             -3.086498
# DEIS.70.S26.001.fa                                             -1.246573
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_oleiciplenus  \
# pos.dna.02.S35.001.fa                                          -2.475253
# CAPMA.83.S12.001.fa                                            -3.675290
# FOGI.63.S13.001.fa                                             -1.696893
# COCL.11.S7.001.fa                                              -0.489334
# WACH.38.S1.001.fa                                              -2.093441
# PRPI.42.S31.001.fa                                             -0.051808
# RODE.80.S8.001.fa                                              -2.030491
# pos.dna.01.S17.001.fa                                          -2.155300
# MEEN.93.S11.001.fa                                             -1.389233
# DETH.41.S27.001.fa                                             -2.735072
# TECA.45.S15.001.fa                                             -1.738692
# BODA.52.S9.001.fa                                              -1.865448
# CHMA.61.S3.001.fa                                               0.945615
# ASTER.02.S34.001.fa                                            -0.424424
# BIRO.74.S19.001.fa                                              1.526685
# CAAU.07.S2.001.fa                                               0.564564
# DIGMA.71.S21.001.fa                                            -0.262493
# FAFE.16.S10.001.fa                                             -1.121834
# OPSE.53.S5.001.fa                                              -0.606017
# LAES.91.S29.001.fa                                              0.495566
# DOEC.81.S30.001.fa                                             -0.129765
# EKJO.64.S32.001.fa                                             -1.907569
# DIAL.15.S23.001.fa                                              0.031977
# GIFI.21.S22.001.fa                                             -2.573181
# TAOT.65.S24.001.fa                                             -2.552559
# DEFI.14.S6.001.fa                                              -1.534714
# MUNA.98.S28.001.fa                                             -1.715021
# ROAL.75.S33.001.fa                                             -1.401189
# MERI.28.S20.001.fa                                             -3.448850
# BUMA.05.S4.001.fa                                              -1.443736
# MOEM.48.S16.001.fa                                              0.683690
# PAMA.46.S18.001.fa                                             -2.977741
# VUGE.37.S14.001.fa                                             -1.232786
# TOSA.76.S25.001.fa                                             -2.393351
# DEIS.70.S26.001.fa                                              0.276297
#
# #OTU ID                k__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__CAG-81;s__CAG-81_sp900066785
# pos.dna.02.S35.001.fa                                          -2.475253
# CAPMA.83.S12.001.fa                                            -3.829440
# FOGI.63.S13.001.fa                                             -2.913825
# COCL.11.S7.001.fa                                              -3.856630
# WACH.38.S1.001.fa                                              -1.995148
# PRPI.42.S31.001.fa                                             -1.882509
# RODE.80.S8.001.fa                                              -1.091414
# pos.dna.01.S17.001.fa                                          -1.703315
# MEEN.93.S11.001.fa                                             -1.218305
# DETH.41.S27.001.fa                                              0.163711
# TECA.45.S15.001.fa                                             -0.965607
# BODA.52.S9.001.fa                                               0.195402
# CHMA.61.S3.001.fa                                              -0.637804
# ASTER.02.S34.001.fa                                             0.490222
# BIRO.74.S19.001.fa                                             -1.350001
# CAAU.07.S2.001.fa                                              -0.054863
# DIGMA.71.S21.001.fa                                             0.456438
# FAFE.16.S10.001.fa                                              0.994868
# OPSE.53.S5.001.fa                                              -1.502694
# LAES.91.S29.001.fa                                             -1.028367
# DOEC.81.S30.001.fa                                             -0.393402
# EKJO.64.S32.001.fa                                             -1.843030
# DIAL.15.S23.001.fa                                             -0.745484
# GIFI.21.S22.001.fa                                             -3.132796
# TAOT.65.S24.001.fa                                             -1.208824
# DEFI.14.S6.001.fa                                              -1.908701
# MUNA.98.S28.001.fa                                             -0.154564
# ROAL.75.S33.001.fa                                             -2.638173
# MERI.28.S20.001.fa                                             -2.688044
# BUMA.05.S4.001.fa                                              -1.600636
# MOEM.48.S16.001.fa                                              0.319989
# PAMA.46.S18.001.fa                                             -2.327154
# VUGE.37.S14.001.fa                                             -0.935806
# TOSA.76.S25.001.fa                                             -2.393351
# DEIS.70.S26.001.fa                                             -3.350707
#
# [35 rows x 181 columns]

# %%
from skbio.stats.composition import ancom

# %%
mask_controls = [not _.startswith("pos") for _ in df_taxa.index]

# %%
df_taxa.index = sample_ids

df_taxa_nc = df_taxa.copy()

df_taxa_nc["sample_id"] = sample_ids

df_taxa_nc = df_taxa_nc.loc[mask_controls].copy()

# %%
df_taxa_nc.shape
# Out:
# (33, 182)

# %%
df_taxa_nc = pd.merge(df_taxa_nc, df_metadata_file[["RDV", "sample_id"]], on="sample_id", how="inner")

# %%
ancom_results = ancom(df_taxa_nc.drop(columns=["RDV", "sample_id"]) + 1, df_taxa_nc["RDV"])[0]

# %%
ancom_results["Reject null hypothesis"].sum()
# Out:
# 0

# %%
df_taxa_clr
# Out:
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Phocaeicola;s__Phocaeicola_vulgatus  \
# pos.dna.02.S35.001.fa                                          12.564805
# CAPMA.83.S12.001.fa                                             1.502473
# FOGI.63.S13.001.fa                                              3.594296
# COCL.11.S7.001.fa                                               1.536088
# WACH.38.S1.001.fa                                               4.240597
# PRPI.42.S31.001.fa                                              3.169797
# RODE.80.S8.001.fa                                               5.918568
# pos.dna.01.S17.001.fa                                          10.758325
# MEEN.93.S11.001.fa                                              4.110142
# DETH.41.S27.001.fa                                              3.183976
# TECA.45.S15.001.fa                                              3.134289
# BODA.52.S9.001.fa                                               4.091882
# CHMA.61.S3.001.fa                                               6.751274
# ASTER.02.S34.001.fa                                             7.511852
# BIRO.74.S19.001.fa                                              6.603156
# CAAU.07.S2.001.fa                                               5.567414
# DIGMA.71.S21.001.fa                                             5.374936
# FAFE.16.S10.001.fa                                              5.584302
# OPSE.53.S5.001.fa                                               7.120223
# LAES.91.S29.001.fa                                              3.183280
# DOEC.81.S30.001.fa                                              4.092462
# EKJO.64.S32.001.fa                                              2.758383
# DIAL.15.S23.001.fa                                              4.740969
# GIFI.21.S22.001.fa                                              3.184368
# TAOT.65.S24.001.fa                                              2.689188
# DEFI.14.S6.001.fa                                               3.475730
# MUNA.98.S28.001.fa                                              2.218994
# ROAL.75.S33.001.fa                                              2.617716
# MERI.28.S20.001.fa                                              1.645391
# BUMA.05.S4.001.fa                                               5.184688
# MOEM.48.S16.001.fa                                              5.631256
# PAMA.46.S18.001.fa                                              2.826640
# VUGE.37.S14.001.fa                                              4.700142
# TOSA.76.S25.001.fa                                              2.213781
# DEIS.70.S26.001.fa                                              2.781823
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_fragilis  \
# pos.dna.02.S35.001.fa                                          12.596202
# CAPMA.83.S12.001.fa                                             0.108900
# FOGI.63.S13.001.fa                                             -0.611240
# COCL.11.S7.001.fa                                               1.074962
# WACH.38.S1.001.fa                                              -0.421227
# PRPI.42.S31.001.fa                                             -1.438640
# RODE.80.S8.001.fa                                              -1.343871
# pos.dna.01.S17.001.fa                                          10.466699
# MEEN.93.S11.001.fa                                              6.091029
# DETH.41.S27.001.fa                                             -3.761992
# TECA.45.S15.001.fa                                              4.631672
# BODA.52.S9.001.fa                                               1.095134
# CHMA.61.S3.001.fa                                               1.924646
# ASTER.02.S34.001.fa                                            -0.131282
# BIRO.74.S19.001.fa                                              4.111350
# CAAU.07.S2.001.fa                                              -1.544217
# DIGMA.71.S21.001.fa                                             0.454759
# FAFE.16.S10.001.fa                                             -0.067135
# OPSE.53.S5.001.fa                                               1.635535
# LAES.91.S29.001.fa                                             -0.423308
# DOEC.81.S30.001.fa                                             -0.679445
# EKJO.64.S32.001.fa                                              1.899094
# DIAL.15.S23.001.fa                                              4.392127
# GIFI.21.S22.001.fa                                              2.202335
# TAOT.65.S24.001.fa                                              1.152850
# DEFI.14.S6.001.fa                                               5.737301
# MUNA.98.S28.001.fa                                             -1.491165
# ROAL.75.S33.001.fa                                              0.620977
# MERI.28.S20.001.fa                                             -2.516686
# BUMA.05.S4.001.fa                                               0.726147
# MOEM.48.S16.001.fa                                              1.947917
# PAMA.46.S18.001.fa                                              1.425925
# VUGE.37.S14.001.fa                                             -1.786927
# TOSA.76.S25.001.fa                                              6.897451
# DEIS.70.S26.001.fa                                              1.181892
#
# #OTU ID                k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia_coli  \
# pos.dna.02.S35.001.fa                                          10.432703
# CAPMA.83.S12.001.fa                                             8.026002
# FOGI.63.S13.001.fa                                              0.322862
# COCL.11.S7.001.fa                                               4.663100
# WACH.38.S1.001.fa                                               2.999156
# PRPI.42.S31.001.fa                                              7.172793
# RODE.80.S8.001.fa                                               4.211689
# pos.dna.01.S17.001.fa                                           8.427199
# MEEN.93.S11.001.fa                                              4.004449
# DETH.41.S27.001.fa                                             -0.928224
# TECA.45.S15.001.fa                                              2.388486
# BODA.52.S9.001.fa                                               0.574600
# CHMA.61.S3.001.fa                                               3.074376
# ASTER.02.S34.001.fa                                            -3.570534
# BIRO.74.S19.001.fa                                             -1.495615
# CAAU.07.S2.001.fa                                              -4.652267
# DIGMA.71.S21.001.fa                                            -1.006752
# FAFE.16.S10.001.fa                                             -1.416951
# OPSE.53.S5.001.fa                                               1.917310
# LAES.91.S29.001.fa                                              5.162297
# DOEC.81.S30.001.fa                                              3.202142
# EKJO.64.S32.001.fa                                              3.268204
# DIAL.15.S23.001.fa                                              1.668718
# GIFI.21.S22.001.fa                                             -0.188357
# TAOT.65.S24.001.fa                                              0.797345
# DEFI.14.S6.001.fa                                               3.139103
# MUNA.98.S28.001.fa                                             -1.683421
# ROAL.75.S33.001.fa                                              1.251969
# MERI.28.S20.001.fa                                              6.880540
# BUMA.05.S4.001.fa                                              -1.573127
# MOEM.48.S16.001.fa                                             -1.263681
# PAMA.46.S18.001.fa                                              0.920859
# VUGE.37.S14.001.fa                                              4.158713
# TOSA.76.S25.001.fa                                             -1.166429
# DEIS.70.S26.001.fa                                              1.358823
#
# #OTU ID                k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia_coli_D  \
# pos.dna.02.S35.001.fa                                          10.382420
# CAPMA.83.S12.001.fa                                             6.006419
# FOGI.63.S13.001.fa                                             -0.505445
# COCL.11.S7.001.fa                                               3.188711
# WACH.38.S1.001.fa                                               1.341303
# PRPI.42.S31.001.fa                                              4.708191
# RODE.80.S8.001.fa                                               4.242758
# pos.dna.01.S17.001.fa                                           8.411471
# MEEN.93.S11.001.fa                                              3.807656
# DETH.41.S27.001.fa                                             -2.920100
# TECA.45.S15.001.fa                                              3.961840
# BODA.52.S9.001.fa                                              -0.936630
# CHMA.61.S3.001.fa                                               2.536282
# ASTER.02.S34.001.fa                                            -3.458830
# BIRO.74.S19.001.fa                                             -1.615759
# CAAU.07.S2.001.fa                                              -5.025247
# DIGMA.71.S21.001.fa                                             0.006649
# FAFE.16.S10.001.fa                                             -2.181225
# OPSE.53.S5.001.fa                                              -0.146372
# LAES.91.S29.001.fa                                              3.618158
# DOEC.81.S30.001.fa                                              3.084641
# EKJO.64.S32.001.fa                                              1.459727
# DIAL.15.S23.001.fa                                              0.472244
# GIFI.21.S22.001.fa                                             -0.344703
# TAOT.65.S24.001.fa                                             -1.012114
# DEFI.14.S6.001.fa                                               5.188512
# MUNA.98.S28.001.fa                                             -2.960675
# ROAL.75.S33.001.fa                                              0.998512
# MERI.28.S20.001.fa                                              5.298956
# BUMA.05.S4.001.fa                                              -1.091536
# MOEM.48.S16.001.fa                                             -1.753768
# PAMA.46.S18.001.fa                                             -0.381243
# VUGE.37.S14.001.fa                                              1.681301
# TOSA.76.S25.001.fa                                             -0.946432
# DEIS.70.S26.001.fa                                              0.169754
#
# #OTU ID                k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia_flexneri  \
# pos.dna.02.S35.001.fa                                          10.717464
# CAPMA.83.S12.001.fa                                             4.688253
# FOGI.63.S13.001.fa                                             -2.583584
# COCL.11.S7.001.fa                                               1.774582
# WACH.38.S1.001.fa                                               0.023436
# PRPI.42.S31.001.fa                                              3.824696
# RODE.80.S8.001.fa                                               4.215763
# pos.dna.01.S17.001.fa                                           8.758813
# MEEN.93.S11.001.fa                                              2.422215
# DETH.41.S27.001.fa                                             -3.462587
# TECA.45.S15.001.fa                                             -0.605582
# BODA.52.S9.001.fa                                              -1.537898
# CHMA.61.S3.001.fa                                               1.136575
# ASTER.02.S34.001.fa                                            -3.434732
# BIRO.74.S19.001.fa                                             -2.541918
# CAAU.07.S2.001.fa                                              -6.750757
# DIGMA.71.S21.001.fa                                            -1.588852
# FAFE.16.S10.001.fa                                             -2.503694
# OPSE.53.S5.001.fa                                              -1.667841
# LAES.91.S29.001.fa                                              2.340659
# DOEC.81.S30.001.fa                                              3.229331
# EKJO.64.S32.001.fa                                              1.149572
# DIAL.15.S23.001.fa                                             -1.063350
# GIFI.21.S22.001.fa                                             -0.019281
# TAOT.65.S24.001.fa                                             -2.398408
# DEFI.14.S6.001.fa                                               0.212743
# MUNA.98.S28.001.fa                                             -3.069716
# ROAL.75.S33.001.fa                                              1.236305
# MERI.28.S20.001.fa                                              5.544301
# BUMA.05.S4.001.fa                                              -2.000538
# MOEM.48.S16.001.fa                                             -2.266186
# PAMA.46.S18.001.fa                                             -0.867528
# VUGE.37.S14.001.fa                                              0.816839
# TOSA.76.S25.001.fa                                             -1.813533
# DEIS.70.S26.001.fa                                             -0.047490
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_bouchesdurhonensis  \
# pos.dna.02.S35.001.fa                                          -0.529343
# CAPMA.83.S12.001.fa                                            -3.136293
# FOGI.63.S13.001.fa                                             -0.913521
# COCL.11.S7.001.fa                                              -2.081677
# WACH.38.S1.001.fa                                              -1.574201
# PRPI.42.S31.001.fa                                             -0.532085
# RODE.80.S8.001.fa                                              -0.235021
# pos.dna.01.S17.001.fa                                          -1.616304
# MEEN.93.S11.001.fa                                             -0.461099
# DETH.41.S27.001.fa                                              0.307518
# TECA.45.S15.001.fa                                             -0.851349
# BODA.52.S9.001.fa                                               0.710902
# CHMA.61.S3.001.fa                                               1.722341
# ASTER.02.S34.001.fa                                             0.951255
# BIRO.74.S19.001.fa                                             -0.057356
# CAAU.07.S2.001.fa                                              -0.619196
# DIGMA.71.S21.001.fa                                            -0.308543
# FAFE.16.S10.001.fa                                              1.577985
# OPSE.53.S5.001.fa                                               1.399707
# LAES.91.S29.001.fa                                             -0.533104
# DOEC.81.S30.001.fa                                             -0.325333
# EKJO.64.S32.001.fa                                              2.914325
# DIAL.15.S23.001.fa                                             -0.037714
# GIFI.21.S22.001.fa                                              2.197504
# TAOT.65.S24.001.fa                                             -0.606649
# DEFI.14.S6.001.fa                                              -1.604646
# MUNA.98.S28.001.fa                                             -2.292634
# ROAL.75.S33.001.fa                                             -0.857894
# MERI.28.S20.001.fa                                             -2.042753
# BUMA.05.S4.001.fa                                              -1.530629
# MOEM.48.S16.001.fa                                              0.196565
# PAMA.46.S18.001.fa                                             -1.068199
# VUGE.37.S14.001.fa                                             -1.146786
# TOSA.76.S25.001.fa                                             -1.793730
# DEIS.70.S26.001.fa                                              4.855276
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Tannerellaceae;g__Parabacteroides;s__Parabacteroides_distasonis_A  \
# pos.dna.02.S35.001.fa                                          -0.683494
# CAPMA.83.S12.001.fa                                             0.814951
# FOGI.63.S13.001.fa                                             -0.274768
# COCL.11.S7.001.fa                                              -2.133863
# WACH.38.S1.001.fa                                              -1.208627
# PRPI.42.S31.001.fa                                              0.522833
# RODE.80.S8.001.fa                                               1.030012
# pos.dna.01.S17.001.fa                                          -0.923157
# MEEN.93.S11.001.fa                                              0.197382
# DETH.41.S27.001.fa                                             -3.401551
# TECA.45.S15.001.fa                                              0.515884
# BODA.52.S9.001.fa                                              -0.204385
# CHMA.61.S3.001.fa                                               1.558442
# ASTER.02.S34.001.fa                                             1.994439
# BIRO.74.S19.001.fa                                             -0.108232
# CAAU.07.S2.001.fa                                               1.828631
# DIGMA.71.S21.001.fa                                            -0.375151
# FAFE.16.S10.001.fa                                              0.749284
# OPSE.53.S5.001.fa                                               3.893911
# LAES.91.S29.001.fa                                             -2.047337
# DOEC.81.S30.001.fa                                              1.312362
# EKJO.64.S32.001.fa                                             -1.524576
# DIAL.15.S23.001.fa                                              1.751842
# GIFI.21.S22.001.fa                                             -1.151795
# TAOT.65.S24.001.fa                                             -1.571730
# DEFI.14.S6.001.fa                                               0.610018
# MUNA.98.S28.001.fa                                             -0.164856
# ROAL.75.S33.001.fa                                             -0.566466
# MERI.28.S20.001.fa                                              0.192413
# BUMA.05.S4.001.fa                                               0.112467
# MOEM.48.S16.001.fa                                              2.102101
# PAMA.46.S18.001.fa                                             -2.690059
# VUGE.37.S14.001.fa                                              0.389677
# TOSA.76.S25.001.fa                                              1.110166
# DEIS.70.S26.001.fa                                             -1.869103
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_uniformis  \
# pos.dna.02.S35.001.fa                                           5.178716
# CAPMA.83.S12.001.fa                                             1.198817
# FOGI.63.S13.001.fa                                              2.714890
# COCL.11.S7.001.fa                                               1.997295
# WACH.38.S1.001.fa                                               2.685130
# PRPI.42.S31.001.fa                                              2.376027
# RODE.80.S8.001.fa                                               2.403992
# pos.dna.01.S17.001.fa                                           3.486100
# MEEN.93.S11.001.fa                                              3.913378
# DETH.41.S27.001.fa                                              1.633435
# TECA.45.S15.001.fa                                              3.626052
# BODA.52.S9.001.fa                                               2.611502
# CHMA.61.S3.001.fa                                               6.117136
# ASTER.02.S34.001.fa                                             3.549830
# BIRO.74.S19.001.fa                                              4.973692
# CAAU.07.S2.001.fa                                               5.706051
# DIGMA.71.S21.001.fa                                             6.540831
# FAFE.16.S10.001.fa                                              5.106302
# OPSE.53.S5.001.fa                                               4.110070
# LAES.91.S29.001.fa                                              4.861458
# DOEC.81.S30.001.fa                                              3.325615
# EKJO.64.S32.001.fa                                              1.952459
# DIAL.15.S23.001.fa                                              3.866595
# GIFI.21.S22.001.fa                                              2.699819
# TAOT.65.S24.001.fa                                              3.131588
# DEFI.14.S6.001.fa                                               3.058043
# MUNA.98.S28.001.fa                                              4.237870
# ROAL.75.S33.001.fa                                              2.787953
# MERI.28.S20.001.fa                                              2.897733
# BUMA.05.S4.001.fa                                               4.452070
# MOEM.48.S16.001.fa                                              4.604422
# PAMA.46.S18.001.fa                                              2.445372
# VUGE.37.S14.001.fa                                              2.790468
# TOSA.76.S25.001.fa                                              2.397261
# DEIS.70.S26.001.fa                                              2.909639
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_faecis  \
# pos.dna.02.S35.001.fa                                           1.714401
# CAPMA.83.S12.001.fa                                             3.197282
# FOGI.63.S13.001.fa                                              0.887994
# COCL.11.S7.001.fa                                               2.537797
# WACH.38.S1.001.fa                                               0.050759
# PRPI.42.S31.001.fa                                              1.803052
# RODE.80.S8.001.fa                                               1.124451
# pos.dna.01.S17.001.fa                                           2.323658
# MEEN.93.S11.001.fa                                              1.410490
# DETH.41.S27.001.fa                                              0.197562
# TECA.45.S15.001.fa                                             -0.435956
# BODA.52.S9.001.fa                                               1.548782
# CHMA.61.S3.001.fa                                               3.203964
# ASTER.02.S34.001.fa                                             2.011697
# BIRO.74.S19.001.fa                                              1.036538
# CAAU.07.S2.001.fa                                               1.065846
# DIGMA.71.S21.001.fa                                             0.876363
# FAFE.16.S10.001.fa                                              6.007668
# OPSE.53.S5.001.fa                                               1.131665
# LAES.91.S29.001.fa                                             -0.527922
# DOEC.81.S30.001.fa                                              4.108773
# EKJO.64.S32.001.fa                                              1.117723
# DIAL.15.S23.001.fa                                             -0.562924
# GIFI.21.S22.001.fa                                              1.567684
# TAOT.65.S24.001.fa                                             -0.432295
# DEFI.14.S6.001.fa                                              -0.740189
# MUNA.98.S28.001.fa                                             -0.495943
# ROAL.75.S33.001.fa                                             -0.119041
# MERI.28.S20.001.fa                                              0.579711
# ...
# TOSA.76.S25.001.fa                                             -2.781117
# DEIS.70.S26.001.fa                                             -3.350707
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Paraprevotella;s__Paraprevotella_sp003477995  \
# pos.dna.02.S35.001.fa                                          -2.475253
# CAPMA.83.S12.001.fa                                            -2.443146
# FOGI.63.S13.001.fa                                             -2.626143
# COCL.11.S7.001.fa                                              -3.594266
# WACH.38.S1.001.fa                                              -1.953475
# PRPI.42.S31.001.fa                                             -1.227844
# RODE.80.S8.001.fa                                              -1.467165
# pos.dna.01.S17.001.fa                                          -2.714916
# MEEN.93.S11.001.fa                                             -3.596317
# DETH.41.S27.001.fa                                             -0.362683
# TECA.45.S15.001.fa                                             -2.342227
# BODA.52.S9.001.fa                                              -0.727855
# CHMA.61.S3.001.fa                                               0.590895
# ASTER.02.S34.001.fa                                             1.110924
# BIRO.74.S19.001.fa                                              1.265571
# CAAU.07.S2.001.fa                                               0.328233
# DIGMA.71.S21.001.fa                                             0.604328
# FAFE.16.S10.001.fa                                             -0.797606
# OPSE.53.S5.001.fa                                               0.762726
# LAES.91.S29.001.fa                                             -2.009986
# DOEC.81.S30.001.fa                                             -2.681997
# EKJO.64.S32.001.fa                                             -3.517006
# DIAL.15.S23.001.fa                                             -1.053558
# GIFI.21.S22.001.fa                                             -2.909653
# TAOT.65.S24.001.fa                                             -2.264877
# DEFI.14.S6.001.fa                                              -3.090619
# MUNA.98.S28.001.fa                                             -4.406562
# ROAL.75.S33.001.fa                                             -2.515834
# MERI.28.S20.001.fa                                             -3.217738
# BUMA.05.S4.001.fa                                              -2.212961
# MOEM.48.S16.001.fa                                             -0.922624
# PAMA.46.S18.001.fa                                             -1.335513
# VUGE.37.S14.001.fa                                             -2.197253
# TOSA.76.S25.001.fa                                             -3.086498
# DEIS.70.S26.001.fa                                             -1.246573
#
# #OTU ID                k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides_oleiciplenus  \
# pos.dna.02.S35.001.fa                                          -2.475253
# CAPMA.83.S12.001.fa                                            -3.675290
# FOGI.63.S13.001.fa                                             -1.696893
# COCL.11.S7.001.fa                                              -0.489334
# WACH.38.S1.001.fa                                              -2.093441
# PRPI.42.S31.001.fa                                             -0.051808
# RODE.80.S8.001.fa                                              -2.030491
# pos.dna.01.S17.001.fa                                          -2.155300
# MEEN.93.S11.001.fa                                             -1.389233
# DETH.41.S27.001.fa                                             -2.735072
# TECA.45.S15.001.fa                                             -1.738692
# BODA.52.S9.001.fa                                              -1.865448
# CHMA.61.S3.001.fa                                               0.945615
# ASTER.02.S34.001.fa                                            -0.424424
# BIRO.74.S19.001.fa                                              1.526685
# CAAU.07.S2.001.fa                                               0.564564
# DIGMA.71.S21.001.fa                                            -0.262493
# FAFE.16.S10.001.fa                                             -1.121834
# OPSE.53.S5.001.fa                                              -0.606017
# LAES.91.S29.001.fa                                              0.495566
# DOEC.81.S30.001.fa                                             -0.129765
# EKJO.64.S32.001.fa                                             -1.907569
# DIAL.15.S23.001.fa                                              0.031977
# GIFI.21.S22.001.fa                                             -2.573181
# TAOT.65.S24.001.fa                                             -2.552559
# DEFI.14.S6.001.fa                                              -1.534714
# MUNA.98.S28.001.fa                                             -1.715021
# ROAL.75.S33.001.fa                                             -1.401189
# MERI.28.S20.001.fa                                             -3.448850
# BUMA.05.S4.001.fa                                              -1.443736
# MOEM.48.S16.001.fa                                              0.683690
# PAMA.46.S18.001.fa                                             -2.977741
# VUGE.37.S14.001.fa                                             -1.232786
# TOSA.76.S25.001.fa                                             -2.393351
# DEIS.70.S26.001.fa                                              0.276297
#
# #OTU ID                k__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__CAG-81;s__CAG-81_sp900066785
# pos.dna.02.S35.001.fa                                          -2.475253
# CAPMA.83.S12.001.fa                                            -3.829440
# FOGI.63.S13.001.fa                                             -2.913825
# COCL.11.S7.001.fa                                              -3.856630
# WACH.38.S1.001.fa                                              -1.995148
# PRPI.42.S31.001.fa                                             -1.882509
# RODE.80.S8.001.fa                                              -1.091414
# pos.dna.01.S17.001.fa                                          -1.703315
# MEEN.93.S11.001.fa                                             -1.218305
# DETH.41.S27.001.fa                                              0.163711
# TECA.45.S15.001.fa                                             -0.965607
# BODA.52.S9.001.fa                                               0.195402
# CHMA.61.S3.001.fa                                              -0.637804
# ASTER.02.S34.001.fa                                             0.490222
# BIRO.74.S19.001.fa                                             -1.350001
# CAAU.07.S2.001.fa                                              -0.054863
# DIGMA.71.S21.001.fa                                             0.456438
# FAFE.16.S10.001.fa                                              0.994868
# OPSE.53.S5.001.fa                                              -1.502694
# LAES.91.S29.001.fa                                             -1.028367
# DOEC.81.S30.001.fa                                             -0.393402
# EKJO.64.S32.001.fa                                             -1.843030
# DIAL.15.S23.001.fa                                             -0.745484
# GIFI.21.S22.001.fa                                             -3.132796
# TAOT.65.S24.001.fa                                             -1.208824
# DEFI.14.S6.001.fa                                              -1.908701
# MUNA.98.S28.001.fa                                             -0.154564
# ROAL.75.S33.001.fa                                             -2.638173
# MERI.28.S20.001.fa                                             -2.688044
# BUMA.05.S4.001.fa                                              -1.600636
# MOEM.48.S16.001.fa                                              0.319989
# PAMA.46.S18.001.fa                                             -2.327154
# VUGE.37.S14.001.fa                                             -0.935806
# TOSA.76.S25.001.fa                                             -2.393351
# DEIS.70.S26.001.fa                                             -3.350707
#
# [35 rows x 181 columns]

# %%
df_taxa_clr.index.name = "sample_id"

df_metadata_file.loc[df_metadata_file["sample_id"] == "MEIR_28", "sample_id"] = "MERI_28"

df_merged = pd.merge(df_taxa_clr, df_metadata_file, on="sample_id", how="left")

# %%
# MERI 28 is misspelled
set(sample_ids).difference(set(df_metadata_file["sample_id"]))

# %%
[col for col in df_merged.columns if "RDV" in col]

# %%
# hospitalization_day
# outcome severe
# CONC_N1

# RDV

# %%
# Veillonella

# %%
df_merged["RDV"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-44d86050273b> in <module>
# ----> 1 df_merged["RDV"]
#
# NameError: name 'df_merged' is not defined

# %%
for col in genera:
    sns.boxplot(x="RDV", y=col, data=df_merged)
    plt.show()

# %%
species = "Enterococcus_faecalis"

[col for col in df_taxa_nc.columns if species in col]
# Out:
# []
