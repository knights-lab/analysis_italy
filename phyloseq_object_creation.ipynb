# %%
library(tidyverse)
library(phyloseq)
library(ape)
library(microbiome)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.0.6     ✔ dplyr   1.0.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# microbiome R package (microbiome.github.com)
#
#
#
#  Copyright (C) 2011-2020 Leo Lahti,
#     Sudarshan Shetty et al. <microbiome.github.io>
#
#
#
# Attaching package: ‘microbiome’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha
#
#
# The following object is masked from ‘package:base’:
#
#     transform

# %%
otu <- read.delim("./data/otu.capitalist.98.tsv", sep = "\t", header = TRUE)

# %%
tax_map <- read.delim('./data/r95.gtdb.tax', sep="\t", header=F)

# %%
colnames(tax_map) <- c('X.OTU.ID', 'tax')

# %%
otu <- tax_map %>% inner_join(otu, by = 'X.OTU.ID')

rownames(otu)<- otu$X.OTU.ID

# %%
taxa <- otu %>% 
  select(tax) %>% 
  separate(tax, c("Domain", "Phylum", "Class", "Order", "Family", "Genus", "Species"),
           ";")

# %%
#the output is a data frame of characters, and we need taxa to be recognized as factors
taxa<- taxa %>% 
  mutate_if(is.character, as.factor)

# taxa<- cbind(otu$X.OTU.ID, taxa)

# colnames(taxa)[1] <- "X.OTU.ID"

otu<- otu %>% 
  select(-X.OTU.ID, -tax)

# rownames(taxa) <- taxa$X.OTU.ID

# taxa <- taxa %>% 
#   select(-X.OTU.ID)

# %%
meta <- read.delim("./data/metadata.csv", sep = ",", header = TRUE)

rownames(meta) <- meta$sample_id

#and delete the first column because it is now redundant
meta<- meta %>% 
        select(-sample_id)

ids <- intersect(rownames(meta), colnames(otu))

# %%
out <- 1:length(colnames(otu))
for (i in 1:length(colnames(otu))) {
    name <- colnames(otu)[i]
    split <- unlist(strsplit(name, "\\."))
    if ( str_starts(split[1], "pos")) {
        out[i] <- toupper(paste0(c(split[1], split[3]), collapse="_"))
    } else {
        out[i] <- toupper(paste0(split[1:2], collapse="_"))
    }    
}
colnames(otu) <- out

# %%
meta <- read.delim("./data/metadata.csv", sep = ",", header = TRUE)

rownames(meta) <- toupper(meta$sample_id)

#and delete the first column because it is now redundant
meta<- meta %>% 
        select(-sample_id)

ids <- intersect(rownames(meta), colnames(otu))

# %%
# otu <- otu %>% rownames_to_column('rn') %>% filter(rn %in% ids)
# rownames(otu) <- otu$rnb
# otu <- otu %>% select(-rn)

# %%
ids
# Out:
#  [1] "MUNA_98"  "BODA_52"  "BUMA_05"  "DEFI_14"  "ROAL_75"  "CHMA_61"
#  [7] "RODE_80"  "LAES_91"  "ASTER_02" "DOEC_81"  "PAMA_46"  "PRPI_42"
# [13] "WACH_38"  "BIRO_74"  "DETH_41"  "FOGI_63"  "GIFI_21"  "TECA_45"
# [19] "DIAL_15"  "MEEN_93"  "CAPMA_83" "MOEM_48"  "DEIS_70"  "DIGMA_71"
# [25] "FAFE_16"  "CAAU_07"  "COCL_11"  "OPSE_53"  "TOSA_76"  "TAOT_65"
# [31] "VUGE_37"  "EKJO_64"  "POS_01"   "POS_02"

# %%
otu <- otu %>% select(ids)
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(ids)` instead of `ids` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
meta <- meta %>% rownames_to_column('rn') %>% filter(rn %in% ids)
rownames(meta) <- meta$rn
meta <- meta %>% select(-rn)

# %%
# taxa <- taxa %>% rownames_to_column('rn') %>% filter(rn %in% ids)
# rownames(taxa) <- taxa$rn
# taxa <- taxa %>% select(-rn)

# %%
otu_mat<- as.matrix(otu)
tax_mat<- as.matrix(taxa)

#transform data to phyloseq objects
phylo_OTU<- otu_table(otu_mat, taxa_are_rows = TRUE)
phylo_TAX<- tax_table(tax_mat)
phylo_samples<- sample_data(meta)

tree <- read.tree("data/r95.gtdb.tree")
#and put them in one object
phylo_object<- phyloseq(phylo_OTU, phylo_TAX, phylo_samples, tree)

# %%
phylo_object
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 7513 taxa and 34 samples ]
# sample_data() Sample Data:       [ 34 samples by 75 sample variables ]
# tax_table()   Taxonomy Table:    [ 7513 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 7513 tips and 7512 internal nodes ]

# %%
sample_sums(phylo_object)
# Out:
#  MUNA_98  BODA_52  BUMA_05  DEFI_14  ROAL_75  CHMA_61  RODE_80  LAES_91
#  9998847 13406694 15854628 17648879  7679409 18129025 11760350 10768004
# ASTER_02  DOEC_81  PAMA_46  PRPI_42  WACH_38  BIRO_74  DETH_41  FOGI_63
# 15903418 15225775 14715906 11883512 23657673 10717625 18653750 14014605
#  GIFI_21  TECA_45  DIAL_15  MEEN_93 CAPMA_83  MOEM_48  DEIS_70 DIGMA_71
# 12308854 12979455 18007421 18931920 17379569 13396754 11255205 36976287
#  FAFE_16  CAAU_07  COCL_11  OPSE_53  TOSA_76  TAOT_65  VUGE_37  EKJO_64
# 15946091 20936056 14733683 15157642 15861922 12437556 15432593  6151250
#   POS_01   POS_02
# 13940787 21389903

# %%
sample_names(phylo_object)
# Out:
#  [1] "MUNA_98"  "BODA_52"  "BUMA_05"  "DEFI_14"  "ROAL_75"  "CHMA_61"
#  [7] "RODE_80"  "LAES_91"  "ASTER_02" "DOEC_81"  "PAMA_46"  "PRPI_42"
# [13] "WACH_38"  "BIRO_74"  "DETH_41"  "FOGI_63"  "GIFI_21"  "TECA_45"
# [19] "DIAL_15"  "MEEN_93"  "CAPMA_83" "MOEM_48"  "DEIS_70"  "DIGMA_71"
# [25] "FAFE_16"  "CAAU_07"  "COCL_11"  "OPSE_53"  "TOSA_76"  "TAOT_65"
# [31] "VUGE_37"  "EKJO_64"  "POS_01"   "POS_02"

# %%
alpha(phylo_object)
# Out:
# Observed richness
#
# Other forms of richness
#
# Diversity
#
# Evenness
#
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Warning message in sum(x) * N:
# “NAs produced by integer overflow”
# Dominance
#
# Rarity
#          observed chao1    diversity_inverse_simpson diversity_gini_simpson
# MUNA_98  2817     3284.040 15.673254                 0.9361970
# BODA_52  3258     3390.036 61.755086                 0.9838070
# BUMA_05  3399     3640.661 17.914212                 0.9441784
# DEFI_14  3230     3536.570  8.719329                 0.8853123
# ROAL_75  2417     2724.347 15.709258                 0.9363433
# CHMA_61  2488     2770.488 15.462326                 0.9353267
# RODE_80  3026     3233.792 14.257733                 0.9298626
# LAES_91  3432     3730.414 26.514556                 0.9622849
# ASTER_02 2654     2959.511  4.673362                 0.7860213
# DOEC_81  3391     3551.046 37.681441                 0.9734617
# PAMA_46  2551     2752.742  4.288269                 0.7668056
# EKJO_64  1978     2549.429 18.545607                 0.9460789
# POS_01   1931     2537.283  8.144669                 0.8772203
# POS_02   1445     1927.227  8.532084                 0.8827953
#          diversity_shannon diversity_fisher diversity_coverage evenness_camargo
# MUNA_98  3.866205          267.5548          7                 NA
# BODA_52  5.053914          304.7165         24                 NA
# BUMA_05  4.189017          313.8480          8                 NA
# DEFI_14  3.339032          293.5231          4                 NA
# ROAL_75  3.632457          232.2653          5                 NA
# CHMA_61  3.796813          219.7800          6                 NA
# RODE_80  3.797458          284.6970          6                 NA
# LAES_91  4.440524          330.2450         10                 NA
# ASTER_02 3.038853          238.9765          2                 NA
# DOEC_81  4.731816          314.3283         16                 NA
# PAMA_46  2.502561          230.5696          2                 NA
# PRPI_42  3.190096          272.6931          3                 NA
# WACH_38  1.855331          197.5505          1                 NA
# BIRO_74  3.844701          206.6020          7                 NA
# DETH_41  4.192751          310.8446          9                 NA
# FOGI_63  2.776772          231.9937          2                 NA
# GIFI_21  2.799163          161.3559          3                 NA
# TECA_45  4.769362          336.0248         14                 NA
# DIAL_15  4.668168          315.9618         14                 NA
# MEEN_93  3.855966          264.6256          6                 NA
# CAPMA_83 1.968231          156.3889          1                 NA
# MOEM_48  3.305702          214.9424          3                 NA
# DEIS_70  2.765387          154.4209          2                 NA
# DIGMA_71 3.614350          274.5854          4                 NA
# FAFE_16  4.688423          327.5213         14                 NA
# CAAU_07  4.046623          287.8153          7                 NA
# COCL_11  2.698709          154.3649          3                 NA
# OPSE_53  3.217511          231.3803          4                 NA
# TOSA_76  1.179123          185.3445          1                 NA
# TAOT_65  2.896623          181.0067          2                 NA
# VUGE_37  4.220968          306.3563          9                 NA
# EKJO_64  3.831316          190.5133          8                 NA
# POS_01   2.456951          170.7300          3                 NA
# POS_02   2.453639          119.4669          4                 NA
#          evenness_pielou evenness_simpson ⋯ dominance_dbp dominance_dmn
# MUNA_98  0.4867175       0.0055638103     ⋯ 0.20157774    0.28356309
# BODA_52  0.6247986       0.0189549068     ⋯ 0.05063426    0.09977732
# BUMA_05  0.5151758       0.0052704359     ⋯ 0.17042311    0.28047041
# DEFI_14  0.4132343       0.0026994828     ⋯ 0.28106352    0.41751383
# ROAL_75  0.4662805       0.0064994861     ⋯ 0.14300762    0.28142621
# CHMA_61  0.4855735       0.0062147613     ⋯ 0.19253567    0.29465517
# RODE_80  0.4737941       0.0047117426     ⋯ 0.19042401    0.32002083
# LAES_91  0.5454587       0.0077256866     ⋯ 0.09570260    0.18910812
# ASTER_02 0.3854542       0.0017608747     ⋯ 0.44969836    0.52435866
# DOEC_81  0.5820993       0.0111121915     ⋯ 0.10238205    0.16105144
# PAMA_46  0.3190316       0.0016810147     ⋯ 0.45379292    0.56085042
# PRPI_42  0.3999148       0.0017472788     ⋯ 0.42950560    0.49829739
# WACH_38  0.2395520       0.0009319097     ⋯ 0.67719551    0.73243218
# BIRO_74  0.4983042       0.0065835278     ⋯ 0.21152998    0.30362370
# DETH_41  0.5152448       0.0045939985     ⋯ 0.21955741    0.28314344
# FOGI_63  0.3539355       0.0021591344     ⋯ 0.39442303    0.50419987
