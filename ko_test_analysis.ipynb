# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# seaborn 0.10.1
# numpy   1.18.4
# pandas  1.0.4

# %%
ko_table = "data/genefamilies.ko.cpm.tsv"
otu_table = "data/otu.capitalist.98.tsv"

taxa_map = "data/r95.gtdb.tax"

# %%
df_ko = pd.read_csv(ko_table, header=0, sep="\t", index_col=0)

# %%
df_otu = pd.read_csv(otu_table, header=0, sep="\t")

# %%
df_taxa_map = pd.read_csv(taxa_map, header=None, sep="\t")
df_taxa_map.columns = ["#OTU ID", "tax"]

# %%
df_tax = pd.merge(df_otu, df_taxa_map, on="#OTU ID", how="left").groupby("tax").sum()

# %%
df_tax
# Out:
#                                                     pos.dna.02.S35.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      1
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                      0
# ...                                                                   ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
#
#                                                     CAPMA.83.S12.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                    0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                    0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                    0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                    0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                    0
# ...                                                                 ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                    0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                    1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                    0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   19
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                    0
#
#                                                     FOGI.63.S13.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   3
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  36
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     COCL.11.S7.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                  0
# ...                                                               ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
#
#                                                     WACH.38.S1.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                  0
# ...                                                               ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
#
#                                                     PRPI.42.S31.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   8
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   3
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 494
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   4
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  29
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     RODE.80.S8.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                  0
# ...                                                               ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                116
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  3
#
#                                                     pos.dna.01.S17.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                      0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                      0
# ...                                                                   ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                    255
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                      0
#
#                                                     MEEN.93.S11.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  55
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     DETH.41.S27.001.fa  ...  \
# tax                                                                     ...
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0  ...
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0  ...
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0  ...
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0  ...
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   7  ...
# ...                                                                ...  ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   4  ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 165  ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1  ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0  ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0  ...
#
#                                                     DEFI.14.S6.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                  1
# ...                                                               ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 24
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 29
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  6
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  6
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  0
#
#                                                     MUNA.98.S28.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  15
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1
#
#                                                     ROAL.75.S33.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   6
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     MERI.28.S20.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 375
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   2
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     BUMA.05.S4.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  1
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                  0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                  2
# ...                                                               ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 10
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                138
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...               2660
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...               1034
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  6
#
#                                                     MOEM.48.S16.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 152
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     PAMA.46.S18.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 113
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     VUGE.37.S14.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                  13
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 402
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                  53
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...              745287
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
#                                                     TOSA.76.S25.001.fa  \
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   5
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   1
#
#                                                     DEIS.70.S26.001.fa
# tax
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                 156
# k__Archaea;p__Halobacteriota;c__Halobacteria;o_...                   0
# k__Archaea;p__Halobacteriota;c__Methanomicrobia...                   0
# ...                                                                ...
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
# k__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                   0
#
# [7513 rows x 35 columns]

# %%
df_ko.columns
# Out:
# Index(['ASTER.02.S34.001.fa_Abundance-CPM', 'BIRO.74.S19.001.fa_Abundance-CPM',
#        'BODA.52.S9.001.fa_Abundance-CPM', 'BUMA.05.S4.001.fa_Abundance-CPM',
#        'CAAU.07.S2.001.fa_Abundance-CPM', 'CAPMA.83.S12.001.fa_Abundance-CPM',
#        'CHMA.61.S3.001.fa_Abundance-CPM', 'COCL.11.S7.001.fa_Abundance-CPM',
#        'DEFI.14.S6.001.fa_Abundance-CPM', 'DEIS.70.S26.001.fa_Abundance-CPM',
#        'DETH.41.S27.001.fa_Abundance-CPM', 'DIAL.15.S23.001.fa_Abundance-CPM',
#        'DIGMA.71.S21.001.fa_Abundance-CPM', 'DOEC.81.S30.001.fa_Abundance-CPM',
#        'EKJO.64.S32.001.fa_Abundance-CPM', 'FAFE.16.S10.001.fa_Abundance-CPM',
#        'FOGI.63.S13.001.fa_Abundance-CPM', 'GIFI.21.S22.001.fa_Abundance-CPM',
#        'LAES.91.S29.001.fa_Abundance-CPM', 'MEEN.93.S11.001.fa_Abundance-CPM',
#        'MERI.28.S20.001.fa_Abundance-CPM', 'MOEM.48.S16.001.fa_Abundance-CPM',
#        'MUNA.98.S28.001.fa_Abundance-CPM', 'OPSE.53.S5.001.fa_Abundance-CPM',
#        'PAMA.46.S18.001.fa_Abundance-CPM', 'PRPI.42.S31.001.fa_Abundance-CPM',
#        'ROAL.75.S33.001.fa_Abundance-CPM', 'RODE.80.S8.001.fa_Abundance-CPM',
#        'TAOT.65.S24.001.fa_Abundance-CPM', 'TECA.45.S15.001.fa_Abundance-CPM',
#        'TOSA.76.S25.001.fa_Abundance-CPM', 'VUGE.37.S14.001.fa_Abundance-CPM',
#        'WACH.38.S1.001.fa_Abundance-CPM',
#        'pos.dna.01.S17.001.fa_Abundance-CPM',
#        'pos.dna.02.S35.001.fa_Abundance-CPM'],
#       dtype='object')

# %%
kos = df_ko.index

# %%
from collections import defaultdict

ungrouped_mask = np.array([not "|" in _ for _ in kos])
k_mask = np.array([_.startswith("K") for _ in kos])

# %%
df_ko = df_ko.loc[ungrouped_mask & k_mask]

df_ko.index
# Out:
# Index(['K00001', 'K00002', 'K00003', 'K00004', 'K00005', 'K00006', 'K00008',
#        'K00009', 'K00010', 'K00012',
#        ...
#        'K19576', 'K19577', 'K19585', 'K19587', 'K19589', 'K19591', 'K19609',
#        'K19610', 'K19611', 'K19648'],
#       dtype='object', name='# Gene Family', length=7220)

# %%
df_ko = df_ko.sort_index(axis=1)
df_tax = df_tax.sort_index(axis=1)

# %%
# we only want species present in greater than 95% of the samples
df_tax = df_tax.T
mask_low_prevalence = ((df_tax > 0).sum(axis=0)) / df_tax.shape[0] >= .8


# mask low abundance
mask_low_abundance = (df_tax.median(axis=0) / df_tax.median().sum()) >= .0001

df_tax = df_tax.loc[:, mask_low_prevalence & mask_low_abundance].T

# %%
df_tax.shape
# Out:
# (455, 35)

# %%
# we only want species present in greater than 95% of the samples
df_ko = df_ko.T
mask_low_prevalence = ((df_ko > 0).sum(axis=0)) / df_ko.shape[0] >= .8


# mask low abundance
mask_low_abundance = (df_ko.median(axis=0) / df_ko.median().sum()) >= .0001

df_ko = df_ko.loc[:, mask_low_prevalence & mask_low_abundance].T

# %%
df_ko.shape
# Out:
# (1325, 35)

# %%
from scipy.stats import spearmanr

rows = []

for ko in df_ko.iterrows():
    rows.append((ko[0], df_tax.apply(lambda x: spearmanr(x, ko[1]), axis=1)))

# %%
from statsmodels.stats.multitest import fdrcorrection
tests = []

for row in rows:
    pvals = np.array([_.pvalue for _ in row[1].values])
    test = fdrcorrection(pvals, alpha=0.25)[0].any()
    tests.append([row[0], test])

# %%
df_results_fdr = pd.DataFrame(tests, columns=["KO", "fdr_any"])

# %%
(~df_results_fdr["fdr_any"]).sum()
# Out:
# 258

# %%
df_results_fdr
# Out:
#           KO  fdr_any
# 0     K00003    False
# 1     K00012     True
# 2     K00013     True
# 3     K00014     True
# 4     K00016     True
# ...      ...      ...
# 1320  K19221    False
# 1321  K19271     True
# 1322  K19302     True
# 1323  K19405     True
# 1324  K19411     True
#
# [1325 rows x 2 columns]

# %%
df_tax.to_csv("data/tax.capitalist.98.a0001.p80.tsv", sep="\t")

df_ko.to_csv("data/ko.98.a0001.p80.tsv", sep="\t")

# %%
df_results_fdr.to_csv("data/ko.fdr.tsv", index=False, sep="\t")

# %%
sig_kos = df_results_fdr.loc[~df_results_fdr.loc[:,'fdr_any'], 'KO']

# %%
df_ko.loc[df_ko.index.isin(sig_kos), :].to_csv("data/ko.fdr.98.a0001.p80.tsv", sep="\t")
